# %% [markdown]
# # Ensemble - RandomForest & ExtraTree
# - 배깅 방식의 앙상블 -> 중복 랜덤 샘플 + 동일 모델(DT)
#     - 대표 알고리즘 : RandomForest C/R
# - 페이스팅 방식의 앙상블 -> 랜덤 샘플 + 동일 모델(DT)
#     - 대표 알고리즘 : ExtraTree C/R

# %% [markdown]
# [목표] 와인 분류 => 0과 1인 2개 종류 분류

# %% [markdown]
# ## [1] 모듈 로딩 및 데이터 준비

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
wine_df = pd.read_csv('../DATA/wine.csv')

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wine_df.head(2)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0

# %%
wine_df['class'].unique()
# Out:
# array([0., 1.])

# %%
# 타겟/라벨의 클래스 분포

wine_df['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %% [markdown]
# 비율이 다르므로 맞추는 방법
# - 다운 샘플링 ( 1.0을 0.0 개수에 맞춤 )
# - 업 샘플링 (0.0을 1.0 개수에 맞춤)

# %%
wine_df.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# 스케일링 한 값과 안 한 값으로 하여 비교해보기

# %% [markdown]
# ## [2] 학습 준비

# %%
# 학습용, 테스트용 데이터셋 분할 

from sklearn.model_selection import train_test_split

# %%
feature_df = wine_df[wine_df.columns[:-1]]
target_sr = wine_df[wine_df.columns[-1]]

print(f'feature_df : {feature_df.shape}, target_sr : {target_sr.shape}')
# Out:
# feature_df : (6497, 3), target_sr : (6497,)

# %%
# 학습용, 테스트용 데이터셋 분리 
x_train, x_test , y_train, y_test = train_test_split(feature_df, target_sr, test_size=0.2, stratify=target_sr, random_state=1)

# %%
print(f'x_train : {x_train.shape}, y_train : {y_train.shape}')
print(f'x_test : {x_test.shape} , y_test : {y_test.shape}')
# Out:
# x_train : (5197, 3), y_train : (5197,)
# x_test : (1300, 3) , y_test : (1300,)

# %% [markdown]
# ## [3] 학습 진행

# %%
# 학습방법 : 지도학습 - 분류 
# 알고리즘 : 앙상블 - 배깅 - RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
# 인스턴스 생성 
# - 100개의 내부 DT 모델에서 사용할 데이터셋 생성 
# - random_state 매개변수 설정을 고정된 데이터셋 생성 
# - oob_score 매개변수 : 샘플 데이터셋 추출 후 남은 데이터셋 검증용으로 사용  
 
# lf_model = RandomForestClassifier(random_state=7,oob_score=True)
lf_model = ExtraTreesClassifier(random_state=7, n_estimators=300) # n_estimators : 생성할 트리의 개수 (default : 100)


# 학습 
lf_model.fit(x_train, y_train)
# Out:
# ExtraTreesClassifier(n_estimators=300, random_state=7)

# %% [markdown]
# ExtraTreesClassifier로 변경했을 때 데이터 수가 많지 않아서 성능 비교가 어려움
#
# -> n_estimator 또는 n_iter를 늘리기
#
# --> 속도가 빠르지만 성능은 좋지 않음

# %%
# 모델 파라미터 
print(f'classes_ : {lf_model.classes_}')
print(f'n_classes_ : {lf_model.n_classes_}개')
print()
print(f'feature_names_in_ : {lf_model.feature_names_in_}')
print(f'n_features_in_ : {lf_model.n_features_in_}개')
print(f'feature_importances_ : {lf_model.feature_importances_}')
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2개
#
# feature_names_in_ : ['alcohol' 'sugar' 'pH']
# n_features_in_ : 3개
# feature_importances_ : [0.19251569 0.52909084 0.27839348]

# %%
# print(f'oob_score_ : {lf_model.oob_score_}')

# %%
# print(f'estimators_samples_ : {lf_model.estimators_samples_}')

# %%
print(f'classes_ : {lf_model.estimator_}')

for est in lf_model.estimators_:
    print(est)
# Out:
# classes_ : ExtraTreeClassifier()
# ExtraTreeClassifier(random_state=327741615)
# ExtraTreeClassifier(random_state=976413892)
# ExtraTreeClassifier(random_state=1202242073)
# ExtraTreeClassifier(random_state=1369975286)
# ExtraTreeClassifier(random_state=1882953283)
# ExtraTreeClassifier(random_state=2053951699)
# ExtraTreeClassifier(random_state=959775639)
# ExtraTreeClassifier(random_state=1956722279)
# ExtraTreeClassifier(random_state=2052949340)
# ExtraTreeClassifier(random_state=1322904761)
# ExtraTreeClassifier(random_state=165338510)
# ExtraTreeClassifier(random_state=1133316631)
# ExtraTreeClassifier(random_state=4812360)
# ExtraTreeClassifier(random_state=372560217)
# ExtraTreeClassifier(random_state=309457262)
# ExtraTreeClassifier(random_state=1801189930)
# ExtraTreeClassifier(random_state=1152936666)
# ExtraTreeClassifier(random_state=68334472)
# ExtraTreeClassifier(random_state=2146978983)
# ExtraTreeClassifier(random_state=119248870)
# ExtraTreeClassifier(random_state=769786948)
# ExtraTreeClassifier(random_state=1583990192)
# ExtraTreeClassifier(random_state=1304549247)
# ExtraTreeClassifier(random_state=1420943751)
# ExtraTreeClassifier(random_state=1636129708)
# ExtraTreeClassifier(random_state=1687674368)
# ExtraTreeClassifier(random_state=283194443)
# ExtraTreeClassifier(random_state=748743479)
# ExtraTreeClassifier(random_state=1237575930)
# ExtraTreeClassifier(random_state=740097030)
# ExtraTreeClassifier(random_state=1759190803)
# ExtraTreeClassifier(random_state=833359292)
# ExtraTreeClassifier(random_state=916483116)
# ExtraTreeClassifier(random_state=1485942463)
# ExtraTreeClassifier(random_state=1941857605)
# ExtraTreeClassifier(random_state=1844809528)
# ExtraTreeClassifier(random_state=1852015768)
# ExtraTreeClassifier(random_state=1127788727)
# ExtraTreeClassifier(random_state=106941365)
# ExtraTreeClassifier(random_state=1077017712)
# ExtraTreeClassifier(random_state=431854331)
# ExtraTreeClassifier(random_state=1094761661)
# ExtraTreeClassifier(random_state=1933291456)
# ExtraTreeClassifier(random_state=1508798754)
# ExtraTreeClassifier(random_state=989143352)
# ExtraTreeClassifier(random_state=747550921)
# ExtraTreeClassifier(random_state=208262606)
# ExtraTreeClassifier(random_state=1248819750)
# ExtraTreeClassifier(random_state=1757192964)
# ExtraTreeClassifier(random_state=1879603694)
# ExtraTreeClassifier(random_state=571958409)
# ExtraTreeClassifier(random_state=1927692119)
# ExtraTreeClassifier(random_state=100556259)
# ExtraTreeClassifier(random_state=1652057283)
# ExtraTreeClassifier(random_state=1075502152)
# ExtraTreeClassifier(random_state=1535344467)
# ExtraTreeClassifier(random_state=725906352)
# ExtraTreeClassifier(random_state=830456065)
# ExtraTreeClassifier(random_state=2008983232)
# ExtraTreeClassifier(random_state=431532432)
# ExtraTreeClassifier(random_state=879820150)
# ExtraTreeClassifier(random_state=2072909727)
# ExtraTreeClassifier(random_state=2107823453)
# ExtraTreeClassifier(random_state=488352684)
# ExtraTreeClassifier(random_state=1599380060)
# ExtraTreeClassifier(random_state=1938096892)
# ExtraTreeClassifier(random_state=2050422343)
# ExtraTreeClassifier(random_state=1497897239)
# ExtraTreeClassifier(random_state=1571487242)
# ExtraTreeClassifier(random_state=1187621609)
# ExtraTreeClassifier(random_state=1451346723)
# ExtraTreeClassifier(random_state=1917728192)
# ExtraTreeClassifier(random_state=1153832253)
# ExtraTreeClassifier(random_state=1966724487)
# ExtraTreeClassifier(random_state=1348596887)
# ExtraTreeClassifier(random_state=771276892)
# ExtraTreeClassifier(random_state=311923447)
# ExtraTreeClassifier(random_state=612959456)
# ExtraTreeClassifier(random_state=1185621653)
# ExtraTreeClassifier(random_state=358664548)
# ExtraTreeClassifier(random_state=1944945571)
# ExtraTreeClassifier(random_state=202873313)
# ExtraTreeClassifier(random_state=1516030531)
# ExtraTreeClassifier(random_state=1332338555)
# ExtraTreeClassifier(random_state=676025563)
# ExtraTreeClassifier(random_state=1214271969)
# ExtraTreeClassifier(random_state=1590645779)
# ExtraTreeClassifier(random_state=1808153499)
# ExtraTreeClassifier(random_state=1971789316)
# ExtraTreeClassifier(random_state=1861190419)
# ExtraTreeClassifier(random_state=941989921)
# ExtraTreeClassifier(random_state=1798548603)
# ExtraTreeClassifier(random_state=1773786398)
# ExtraTreeClassifier(random_state=2088312505)
# ExtraTreeClassifier(random_state=1745574629)
# ExtraTreeClassifier(random_state=1260873545)
# ExtraTreeClassifier(random_state=775033821)
# ExtraTreeClassifier(random_state=1474484177)
# ExtraTreeClassifier(random_state=1035597695)
# ExtraTreeClassifier(random_state=1289946527)
# ExtraTreeClassifier(random_state=1814082690)
# ExtraTreeClassifier(random_state=16987219)
# ExtraTreeClassifier(random_state=1831604146)
# ExtraTreeClassifier(random_state=529379730)
# ExtraTreeClassifier(random_state=577157141)
# ExtraTreeClassifier(random_state=674190967)
# ExtraTreeClassifier(random_state=98381379)
# ExtraTreeClassifier(random_state=1112979659)
# ExtraTreeClassifier(random_state=1781921722)
# ExtraTreeClassifier(random_state=1740316719)
# ExtraTreeClassifier(random_state=6128400)
# ExtraTreeClassifier(random_state=718379532)
# ExtraTreeClassifier(random_state=396263773)
# ExtraTreeClassifier(random_state=1887643755)
# ExtraTreeClassifier(random_state=899342057)
# ExtraTreeClassifier(random_state=1210044809)
# ExtraTreeClassifier(random_state=104563532)
# ExtraTreeClassifier(random_state=792975171)
# ExtraTreeClassifier(random_state=842502766)
# ExtraTreeClassifier(random_state=1016509070)
# ExtraTreeClassifier(random_state=1956221564)
# ExtraTreeClassifier(random_state=2102055188)
# ExtraTreeClassifier(random_state=785609013)
# ExtraTreeClassifier(random_state=1949878268)
# ExtraTreeClassifier(random_state=228185999)
# ExtraTreeClassifier(random_state=660304699)
# ExtraTreeClassifier(random_state=1326512163)
# ExtraTreeClassifier(random_state=640460592)
# ExtraTreeClassifier(random_state=397691140)
# ExtraTreeClassifier(random_state=246589227)
# ExtraTreeClassifier(random_state=1009834440)
# ExtraTreeClassifier(random_state=1582831066)
# ExtraTreeClassifier(random_state=1997035258)
# ExtraTreeClassifier(random_state=616877622)
# ExtraTreeClassifier(random_state=1911467563)
# ExtraTreeClassifier(random_state=1923734511)
# ExtraTreeClassifier(random_state=1496370391)
# ExtraTreeClassifier(random_state=683901901)
# ExtraTreeClassifier(random_state=2028616114)
# ExtraTreeClassifier(random_state=694538279)
# ExtraTreeClassifier(random_state=1466631299)
# ExtraTreeClassifier(random_state=1454132637)
# ExtraTreeClassifier(random_state=563115916)
# ExtraTreeClassifier(random_state=139833804)
# ExtraTreeClassifier(random_state=1326000975)
# ExtraTreeClassifier(random_state=170278685)
# ExtraTreeClassifier(random_state=1988554376)
# ExtraTreeClassifier(random_state=410591798)
# ExtraTreeClassifier(random_state=1038725798)
# ExtraTreeClassifier(random_state=1283744117)
# ExtraTreeClassifier(random_state=2086603462)
# ExtraTreeClassifier(random_state=1728245397)
# ExtraTreeClassifier(random_state=587878444)
# ExtraTreeClassifier(random_state=783625179)
# ExtraTreeClassifier(random_state=1475478151)
# ExtraTreeClassifier(random_state=8261329)
# ExtraTreeClassifier(random_state=1393399786)
# ExtraTreeClassifier(random_state=1705865711)
# ExtraTreeClassifier(random_state=1290289349)
# ExtraTreeClassifier(random_state=1227573348)
# ExtraTreeClassifier(random_state=710823092)
# ExtraTreeClassifier(random_state=1938473961)
# ExtraTreeClassifier(random_state=1781989545)
# ExtraTreeClassifier(random_state=1107906589)
# ExtraTreeClassifier(random_state=1924663578)
# ExtraTreeClassifier(random_state=85391168)
# ExtraTreeClassifier(random_state=1180688124)
# ExtraTreeClassifier(random_state=1580992702)
# ExtraTreeClassifier(random_state=1272988374)
# ExtraTreeClassifier(random_state=1972942562)
# ExtraTreeClassifier(random_state=96164876)
# ExtraTreeClassifier(random_state=472470150)
# ExtraTreeClassifier(random_state=1978392040)
# ExtraTreeClassifier(random_state=1284204450)
# ExtraTreeClassifier(random_state=1194918331)
# ExtraTreeClassifier(random_state=2138546282)
# ExtraTreeClassifier(random_state=1663393390)
# ExtraTreeClassifier(random_state=846862196)
# ExtraTreeClassifier(random_state=751270385)
# ExtraTreeClassifier(random_state=1615230301)
# ExtraTreeClassifier(random_state=1290547686)
# ExtraTreeClassifier(random_state=1151800554)
# ExtraTreeClassifier(random_state=1885968913)
# ExtraTreeClassifier(random_state=1017641989)
# ExtraTreeClassifier(random_state=174615375)
# ExtraTreeClassifier(random_state=1600274481)
# ExtraTreeClassifier(random_state=1613497782)
# ExtraTreeClassifier(random_state=1657443660)
# ExtraTreeClassifier(random_state=1187829353)
# ExtraTreeClassifier(random_state=1001116648)
# ExtraTreeClassifier(random_state=2043392988)
# ExtraTreeClassifier(random_state=754966710)
# ExtraTreeClassifier(random_state=1274578607)
# ExtraTreeClassifier(random_state=1711569317)
# ExtraTreeClassifier(random_state=933048265)
# ExtraTreeClassifier(random_state=1467288151)
# ExtraTreeClassifier(random_state=631994005)
# ExtraTreeClassifier(random_state=1231498500)
# ExtraTreeClassifier(random_state=681818587)
# ExtraTreeClassifier(random_state=604650060)
# ExtraTreeClassifier(random_state=297435369)
# ExtraTreeClassifier(random_state=2130377035)
# ExtraTreeClassifier(random_state=1533606662)
# ExtraTreeClassifier(random_state=2031759224)
# ExtraTreeClassifier(random_state=1343592673)
# ExtraTreeClassifier(random_state=2036822485)
# ExtraTreeClassifier(random_state=1836978261)
# ExtraTreeClassifier(random_state=1905149598)
# ExtraTreeClassifier(random_state=428871531)
# ExtraTreeClassifier(random_state=1021340124)
# ExtraTreeClassifier(random_state=979945272)
# ExtraTreeClassifier(random_state=178554675)
# ExtraTreeClassifier(random_state=1379662071)
# ExtraTreeClassifier(random_state=1107158199)
# ExtraTreeClassifier(random_state=1118903929)
# ExtraTreeClassifier(random_state=57556876)
# ExtraTreeClassifier(random_state=30680140)
# ExtraTreeClassifier(random_state=766332781)
# ExtraTreeClassifier(random_state=1804989348)
# ExtraTreeClassifier(random_state=1683633863)
# ExtraTreeClassifier(random_state=1989154901)
# ExtraTreeClassifier(random_state=1888036538)
# ExtraTreeClassifier(random_state=238368553)
# ExtraTreeClassifier(random_state=914478310)
# ExtraTreeClassifier(random_state=177992591)
# ExtraTreeClassifier(random_state=1345597227)
# ExtraTreeClassifier(random_state=462871867)
# ExtraTreeClassifier(random_state=1733657426)
# ExtraTreeClassifier(random_state=1410695743)
# ExtraTreeClassifier(random_state=372463516)
# ExtraTreeClassifier(random_state=1897556368)
# ExtraTreeClassifier(random_state=798859141)
# ExtraTreeClassifier(random_state=550390819)
# ExtraTreeClassifier(random_state=1341414989)
# ExtraTreeClassifier(random_state=989692192)
# ExtraTreeClassifier(random_state=347236981)
# ExtraTreeClassifier(random_state=683580119)
# ExtraTreeClassifier(random_state=1919560671)
# ExtraTreeClassifier(random_state=568971425)
# ExtraTreeClassifier(random_state=1280249901)
# ExtraTreeClassifier(random_state=962410408)
# ExtraTreeClassifier(random_state=190146164)
# ExtraTreeClassifier(random_state=321532379)
# ExtraTreeClassifier(random_state=1797085582)
# ExtraTreeClassifier(random_state=728098861)
# ExtraTreeClassifier(random_state=82277225)
# ExtraTreeClassifier(random_state=1212169258)
# ExtraTreeClassifier(random_state=789302112)
# ExtraTreeClassifier(random_state=1533198626)
# ExtraTreeClassifier(random_state=2096364639)
# ExtraTreeClassifier(random_state=144629616)
# ExtraTreeClassifier(random_state=947382455)
# ExtraTreeClassifier(random_state=140208358)
# ExtraTreeClassifier(random_state=217080722)
# ExtraTreeClassifier(random_state=1275396361)
# ExtraTreeClassifier(random_state=97028041)
# ExtraTreeClassifier(random_state=2040709389)
# ExtraTreeClassifier(random_state=2094021973)
# ExtraTreeClassifier(random_state=1177931691)
# ExtraTreeClassifier(random_state=1129711617)
# ExtraTreeClassifier(random_state=726283551)
# ExtraTreeClassifier(random_state=117191566)
# ExtraTreeClassifier(random_state=1617918160)
# ExtraTreeClassifier(random_state=2080764464)
# ExtraTreeClassifier(random_state=1757425305)
# ExtraTreeClassifier(random_state=530099697)
# ExtraTreeClassifier(random_state=848397294)
# ExtraTreeClassifier(random_state=556442785)
# ExtraTreeClassifier(random_state=1896355797)
# ExtraTreeClassifier(random_state=1760820179)
# ExtraTreeClassifier(random_state=941594879)
# ExtraTreeClassifier(random_state=1986506066)
# ExtraTreeClassifier(random_state=1483246144)
# ExtraTreeClassifier(random_state=365500877)
# ExtraTreeClassifier(random_state=722736954)
# ExtraTreeClassifier(random_state=708230410)
# ExtraTreeClassifier(random_state=708536318)
# ExtraTreeClassifier(random_state=1681880500)
# ExtraTreeClassifier(random_state=1322143226)
# ExtraTreeClassifier(random_state=1909348891)
# ExtraTreeClassifier(random_state=213520540)
# ExtraTreeClassifier(random_state=1474853896)
# ExtraTreeClassifier(random_state=707452663)
# ExtraTreeClassifier(random_state=880770529)
# ExtraTreeClassifier(random_state=152595044)
# ExtraTreeClassifier(random_state=1988083673)
# ExtraTreeClassifier(random_state=1209178540)
# ExtraTreeClassifier(random_state=1661253374)
# ExtraTreeClassifier(random_state=1322295219)
# ExtraTreeClassifier(random_state=122116918)
# ExtraTreeClassifier(random_state=192269610)
# ExtraTreeClassifier(random_state=1381647708)
# ExtraTreeClassifier(random_state=35289607)
# ExtraTreeClassifier(random_state=594754289)
# ExtraTreeClassifier(random_state=1553131663)
# ExtraTreeClassifier(random_state=1558595200)
# ExtraTreeClassifier(random_state=273255634)
# ExtraTreeClassifier(random_state=586806503)
# ExtraTreeClassifier(random_state=642038764)
# ExtraTreeClassifier(random_state=2144464560)

# %% [markdown]
# ## [4] 성능 평가

# %%
train_score = lf_model.score(x_train, y_train)
test_score = lf_model.score(x_test, y_test)

print(f'train_score : {train_score}, test_score : {test_score}')
# Out:
# train_score : 0.9973061381566288, test_score : 0.8992307692307693

# %% [markdown]
# -> 과대적합

# %% [markdown]
# ## [5] 튜닝
# - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     - 범위가 넓은 하이퍼 파라미터 설정에 좋음
#     - 지정된 범위에서 지정된 횟수만큼 하이퍼파라미터 추출하여 조합 진행

# %%
# 모듈 로딩 
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestClassifier 하이퍼 파라미터 설정 
params = {'max_depth' : range(2,16), 
          'min_samples_leaf' : range(5,16),
          'criterion' : ['gini','entropy','log_loss']}

# %%
rf_model = RandomForestClassifier(random_state=7)

# %%
search_cv = RandomizedSearchCV(rf_model, param_distributions=params, n_iter=50, verbose=4) 
# verbose : 진행단계 보여줌

# %%
search_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.842 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.854 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.858 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.848 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.841 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.857 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.859 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.838 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.886 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.846 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.882 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.876 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=12;, score=0.835 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=12;, score=0.833 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=12;, score=0.853 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=12;, score=0.859 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=12;, score=0.843 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=14, min_samples_leaf=13;, score=0.872 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=14, min_samples_leaf=13;, score=0.838 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=14, min_samples_leaf=13;, score=0.878 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=14, min_samples_leaf=13;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=14, min_samples_leaf=13;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=8, min_samples_leaf=15;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=8, min_samples_leaf=15;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=8, min_samples_leaf=15;, score=0.874 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=8, min_samples_leaf=15;, score=0.882 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=8, min_samples_leaf=15;, score=0.866 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.870 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.838 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.877 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.884 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.865 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.756 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.771 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.875 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.875 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.834 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.872 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.883 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.870 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.832 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth
total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.832 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.873 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.879 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=13;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_leaf=11;, score=0.799 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_leaf=11;, score=0.801 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_leaf=11;, score=0.808 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_leaf=11;, score=0.825 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_leaf=11;, score=0.819 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.873 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.842 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.879 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=10, min_samples_leaf=6;, score=0.873 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=10, min_samples_leaf=6;, score=0.846 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=10, min_samples_leaf=6;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=10, min_samples_leaf=6;, score=0.881 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=10, min_samples_leaf=6;, score=0.874 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=11;, score=0.871 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=11;, score=0.837 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=11;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=11;, score=0.882 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=11;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.872 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.836 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.880 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.883 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.873 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.873 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.882 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=12;, score=0.854 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=12;, score=0.836 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=12;, score=0.861 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=12;, score=0.875 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=12;, score=0.859 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=9;, score=0.874 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=9;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=9;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=9;, score=0.880 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=9;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.888 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.848 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.880 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.889 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.883 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.863 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.833 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.870 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.880 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.861 total time=   0.1s
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=7), n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터 
print(f'[search_cv.best_score_] {search_cv.best_score_}')
print(f'[search_cv.best_param] {search_cv.best_params_}')
print(f'[search_cv.best_estimator_] {search_cv.best_estimator_}')

cv_result_df = pd.DataFrame(search_cv.cv_results_)
cv_result_df
# Out:
# [search_cv.best_score_] 0.8776253053972015
# [search_cv.best_param] {'min_samples_leaf': 5, 'max_depth': 15, 'criterion': 'log_loss'}
# [search_cv.best_estimator_] RandomForestClassifier(criterion='log_loss', max_depth=15, min_samples_leaf=5,
#                        random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0
# 8                      14              12         entropy
# 9                      13              12            gini
# 10                     12              15            gini
# 11                      7               2         entropy
# 12                     14               9            gini
# 13                     13              10        log_loss
# 14                     10               4         entropy
# 15                      7              11         entropy
# 16                      5              15            gini
# 17                     11               9        log_loss
# 18                     15               2            gini
# 19                      9              11        log_loss
# 20                     14              10            gini
# 21                      5               5         entropy
# 22                      7               7         entropy
# 23                     14              11         entropy
# 24                     10               6        log_loss
# 25                      6              14         entropy
# 26                     13               4        log_loss
# 27                      5               3        log_loss
# 28                     12              14        log_loss
# 29                      6               8            gini
# 30                     12              13            gini
# 31                      7               7            gini
# 32                     12               2         entropy
# 33                      8               2        log_loss
# 34                     15              13         entropy
# 35                     14               8         entropy
# 36                     15               4            gini
# 37                     10              14         entropy
# 38                      9              12         entropy
# 39                     13              15            gini
# 40                     11               3         entropy
# 41                      7               9        log_loss
# 42                      6              10        log_loss
# 43                     11               9         entropy
# 44                     10              15            gini
# 45                     10              10            gini
# 46                     12               5        log_loss
# 47                      9              11         entropy
# 48                      5              15        log_loss
# 49                     15               6        log_loss
#
#                                                params  split0_test_score  \
# 0   {'min_samples_leaf': 5, 'max_depth': 4, 'crite...           0.842308
# 1   {'min_samples_leaf': 10, 'max_depth': 4, 'crit...           0.841346
# 2   {'min_samples_leaf': 7, 'max_depth': 12, 'crit...           0.885577
# 3   {'min_samples_leaf': 12, 'max_depth': 4, 'crit...           0.834615
# 4   {'min_samples_leaf': 13, 'max_depth': 14, 'cri...           0.872115
# 5   {'min_samples_leaf': 15, 'max_depth': 8, 'crit...           0.872115
# 6   {'min_samples_leaf': 15, 'max_depth': 9, 'crit...           0.870192
# 7   {'min_samples_leaf': 8, 'max_depth': 2, 'crite...           0.755769
# 8   {'min_samples_leaf': 14, 'max_depth': 12, 'cri...           0.875000
# 9   {'min_samples_leaf': 13, 'max_depth': 12, 'cri...           0.875000
# 10  {'min_samples_leaf': 12, 'max_depth': 15, 'cri...           0.872115
# 11  {'min_samples_leaf': 7, 'max_depth': 2, 'crite...           0.753846
# 12  {'min_samples_leaf': 14, 'max_depth': 9, 'crit...           0.867308
# 13  {'min_samples_leaf': 13, 'max_depth': 10, 'cri...           0.872115
# 14  {'min_samples_leaf': 10, 'max_depth': 4, 'crit...           0.832692
# 15  {'min_samples_leaf': 7, 'max_depth': 11, 'crit...           0.881731
# 16  {'min_samples_leaf': 5, 'max_depth': 15, 'crit...           0.886538
# 17  {'min_samples_leaf': 11, 'max_depth': 9, 'crit...           0.871154
# 18  {'min_samples_leaf': 15, 'max_depth': 2, 'crit...           0.755769
# 19  {'min_samples_leaf': 9, 'max_depth': 11, 'crit...           0.874038
# 20  {'min_samples_leaf': 14, 'max_depth': 10, 'cri...           0.875000
# 21  {'min_samples_leaf': 5, 'max_depth': 5, 'crite...           0.850962
# 22  {'min_samples_leaf': 7, 'max_depth': 7, 'crite...           0.864423
# 23  {'min_samples_leaf': 14, 'max_depth': 11, 'cri...           0.875962
# 24  {'min_samples_leaf': 10, 'max_depth': 6, 'crit...           0.861538
# 25  {'min_samples_leaf': 6, 'max_depth': 14, 'crit...           0.879808
# 26  {'min_samples_leaf': 13, 'max_depth': 4, 'crit...           0.834615
# 27  {'min_samples_leaf': 5, 'max_depth': 3, 'crite...           0.798077
# 28  {'min_samples_leaf': 12, 'max_depth': 14, 'cri...           0.875962
# 29  {'min_samples_leaf': 6, 'max_depth': 8, 'crite...           0.874038
# 30  {'min_samples_leaf': 12, 'max_depth': 13, 'cri...           0.873077
# 31  {'min_samples_leaf': 7, 'max_depth': 7, 'crite...           0.868269
# 32  {'min_samples_leaf': 12, 'max_depth': 2, 'crit...           0.753846
# 33  {'min_samples_leaf': 8, 'max_depth': 2, 'crite...           0.753846
# 34  {'min_samples_leaf': 15, 'max_depth': 13, 'cri...           0.873077
# 35  {'min_samples_leaf': 14, 'max_depth': 8, 'crit...           0.871154
# 36  {'min_samples_leaf': 15, 'max_depth': 4, 'crit...           0.842308
# 37  {'min_samples_leaf': 10, 'max_depth': 14, 'cri...           0.876923
# 38  {'min_samples_leaf': 9, 'max_depth': 12, 'crit...           0.875962
# 39  {'min_samples_leaf': 13, 'max_depth': 15, 'cri...           0.875000
# 40  {'min_samples_leaf': 11, 'max_depth': 3, 'crit...           0.799038
# 41  {'min_samples_leaf': 7, 'max_depth': 9, 'crite...           0.873077
# 42  {'min_samples_leaf': 6, 'max_depth': 10, 'crit...           0.873077
# 43  {'min_samples_leaf': 11, 'max_depth': 9, 'crit...           0.871154
# 44  {'min_samples_leaf': 10, 'max_depth': 15, 'cri...           0.872115
# 45  {'min_samples_leaf': 10, 'max_depth': 10, 'cri...           0.873077
# 46  {'min_samples_leaf': 12, 'max_depth': 5, 'crit...           0.853846
# 47  {'min_samples_leaf': 9, 'max_depth': 11, 'crit...           0.874038
# 48  {'min_samples_leaf': 5, 'max_depth': 15, 'crit...           0.888462
# 49  {'min_samples_leaf': 15, 'max_depth': 6, 'crit...           0.862500
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.837500           0.853705           0.857555
# 1            0.838462           0.856593           0.859480
# 2            0.846154           0.881617           0.885467
# 3            0.832692           0.852743           0.859480
# 4            0.837500           0.877767           0.884504
# 5            0.836538           0.873917           0.881617
# 6            0.838462           0.876805           0.883542
# 7            0.767308           0.770934           0.753609
# 8            0.839423           0.875842           0.883542
# 9            0.833654           0.871992           0.882579
# 10           0.831731           0.880654           0.882579
# 11           0.753846           0.754572           0.753609
# 12           0.836538           0.874880           0.877767
# 13           0.834615           0.871030           0.884504
# 14           0.838462           0.853705           0.857555
# 15           0.844231           0.875842           0.883542
# 16           0.847115           0.881617           0.889317
# 17           0.836538           0.875842           0.881617
# 18           0.767308           0.770934           0.753609
# 19           0.839423           0.876805           0.879692
# 20           0.831731           0.878730           0.880654
# 21           0.842308           0.858518           0.874880
# 22           0.834615           0.873917           0.879692
# 23           0.836538           0.876805           0.883542
# 24           0.831731           0.871992           0.875842
# 25           0.841346           0.880654           0.885467
