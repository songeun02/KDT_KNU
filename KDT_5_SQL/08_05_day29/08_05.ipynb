# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - 2005-06-16 포함 x
#   - 포함하려면 모든 경계를 포함하는 BETWEEN 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - ^ : 시작

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - 2005-08-31 까지
#   - 시간 때문에 포함 x
#   - 2005-09-01의 00:00:00 까지는 포함
# => date() 사용하면 됨
