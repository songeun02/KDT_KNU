# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - name 은 최대 30글자만 받음

# %% [markdown]
# # MYSQL 자료형

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - 괄호 안 숫자는 크기
# - 2^8인 최대 255바이트

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 변수 이름만 대소문자 구분

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - ENUM() : 이 중에 하나 선택

# %%
desc person; # 생성한 테이블 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - 기존에서 auto_increment 추가

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - table 외부 변경 : alter
# - table 내부 데이터 변경 : update

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
