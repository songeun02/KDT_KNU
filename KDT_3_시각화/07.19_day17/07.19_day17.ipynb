# %% [markdown]
# # 멀티인덱스
# - 멀티인덱스는 클래스
#   - 클래스 안에 있는게 속성
#
# - 2개 이상의 행과 열로 구성된 인덱스
#
# - 멀티인덱스의 열을 레벨이라고 함

# %%
import pandas as pd

# %%
file='/content/drive/MyDrive/KDT AI, 빅데이터 전문가 양성과정/data/07_19/test_data.csv'
file2='/content/drive/MyDrive/KDT AI, 빅데이터 전문가 양성과정/data/07_19/test_data2.csv'

# %%
df=pd.read_csv(file)
df2=pd.read_csv(file2)

# %%
# 데이터 확인
# - 기본정보

# df.info()
# print(f'[index] : {df.index}')
# print(f'[columns] : {df.columns}')

# df2.info()
# print(f'[index] : {df2.index}')
# print(f'[columns] : {df2.columns}')

# %%
import df_util as util

# %% [markdown]
# # 그룹화 처리
# - Series / DataFrame에 groupby() 메서드 사용
# - Series / DataFrame GroupBy Object 결과로 반환
