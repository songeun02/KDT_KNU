# %% [markdown]
# p193
#
# 16.5

# %%
x = [49,-17,25,102,8,62,21]

for i in x:
  print(i*10, end=' ')
# Out:
# 490 -170 250 1020 80 620 210

# %% [markdown]
# 16.6

# %%
num = int(input())

for i in range(1,10):
  print(f'{num} * {i} = {num*i}')
# Out:
# 2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
