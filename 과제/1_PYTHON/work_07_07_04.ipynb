# %% [markdown]
# p270
#
# 22.9

# %%
a=['alpha','bravo','charlie','delta','echo','foxtrot','golf','hotel','india']
b=[i for i in a if len(i)==5]

print(b)
# Out:
# ['alpha', 'bravo', 'delta', 'hotel', 'india']

# %% [markdown]
# p271
#
# 22.10

# %%
start, end = map(int,input().split())
a=[]

for i in range(start, end+1):
  if 1<=start<=20 and 10<=end<=30:
    if start<end:
      a.append(2**i)

del a[1], a[-2]

print(a)
# Out:
# 10 20
# [1024, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 1048576]

# %%
start, end = map(int,input().split())
a=[2**i for i in range(start, end+1) if 1<=start<=20 and 10<=end<=30 if start<end]

del a[1], a[-2]

print(a)
# Out:
# 10 20
# [1024, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 1048576]

# %% [markdown]
# p328
#
# 25.7

# %%
maria={'korea':94, 'english':91,'mathematics':89,'science':83}
average=sum(maria.values())/len(maria)

print(average)
# Out:
# 89.25

# %% [markdown]
# 25.8

# %%
k=input().split()
v=input().split()
x={}
d={}

d.update(zip(k,v))

d.pop('delta','없음')

for key, value in d.items():
  if value!='30':
    x.setdefault(key,value)


print(d)
print(x)
# Out:
# alpha bravo charlie delta
# 10 20 30 40
# {'alpha': '10', 'bravo': '20', 'charlie': '30'}
# {'alpha': '10', 'bravo': '20'}
