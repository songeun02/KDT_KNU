# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
house = pd.read_csv('/content/drive/MyDrive/KDT AI, 빅데이터 전문가 양성과정/data/7_Statistics&Numpy/08_19/BostonHousing.csv')
house_df = house['medv']

# %% [markdown]
# 1. 주택 가격의 평균

# %%
house_df.mean()
# Out:
# 22.532806324110677

# %% [markdown]
# 2. 주택 가격의 중앙값

# %%
house_df.median()
# Out:
# 21.2

# %% [markdown]
# 3. 주택 가격의 표준편차

# %%
np.std(house_df)
# Out:
# 9.188011545278203

# %% [markdown]
# 4. 주태 가격의 최대값

# %%
np.max(house_df)
# Out:
# 50.0

# %% [markdown]
# 5. 주택 가격의 최소값

# %%
np.min(house_df)
# Out:
# 5.0

# %% [markdown]
# 6. 주택 가격의 최빈값

# %%
house_df.mode()
# Out:
# 0    50.0
# Name: medv, dtype: float64

# %% [markdown]
# 7. 주택 가격의 분포를 시각화

# %%
plt.hist(house_df)
plt.title('Boston House Prices')
plt.show()
