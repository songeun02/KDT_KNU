# %% [markdown]
# [순수 프로그래밍 -> 파이썬]
#
# int float bool : 원시 데이터 타입(primitive type)
#
# list tuple dict set : 컬렉션 데이터 타입(collection type)
#
#
#
# ---
#
# [데이터분석 프로그래밍] -> 파이썬 사용해서 판다스

# %% [markdown]
# ** csv : comma로 데이터 구분

# %% [markdown]
# 여러 데이터 파일 형식을 하나의 형식으로 통합하기 위해 dataframe 사용

# %% [markdown]
# class list, class str은 속성이 없었지만
#
# class DataFrame은 속성 존재

# %% [markdown]
# scalar(스칼라) : 숫자 1개
