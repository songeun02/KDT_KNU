# %% [markdown]
# # CSV 파일 DF으로 저장

# %%
import pandas as pd

# %%
# 데이터 준비 - 파일
data_file=r'/content/drive/MyDrive/KDT AI, 빅데이터 전문가 양성과정/PANDAS/data.csv'

# %%
# csv 파일 -> DF로 저장
csvDF=pd.read_csv(data_file)

# %%
csvDF
# Out:
#    no  name  age gender
# 0   1  Hong   10      F
# 1   2  Park   13      F
# 2   3   Kim   12      M
# 3   4   Lee   16      F
# 4   5   Lim   15      M

# %%
# 데이터 준비 - 파일
data_file1=r'/content/drive/MyDrive/KDT AI, 빅데이터 전문가 양성과정/PANDAS/data1.csv'

# %%
# csv 파일 -> DF로 저장
csvDF1=pd.read_csv(data_file1)
csvDF1
# Out:
#    1 Hong 10 F
# 0  2 Park 13 F
# 1   3 Kim 12 M
# 2   4 Lee 16 F
# 3   5 Lim 15 M

# %%
csvDF1.columns # 열 인덱스가 첫번째 데이터
# Out:
# Index(['1 Hong 10 F'], dtype='object')

# %%
csvDF1.index # 총 데이터는 5개지만 index는 4까지
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# csv 파일 -> DF로 저장 -> 구분자가 공백
csvDF1=pd.read_csv(data_file1,sep=' ')
csvDF1
# Out:
#    1  Hong  10  F
# 0  2  Park  13  F
# 1  3   Kim  12  M
# 2  4   Lee  16  F
# 3  5   Lim  15  M

# %% [markdown]
# 파일을 열어서 데이터 구분자 파악해서 적용

# %%
# csv 파일 -> DF로 저장 -> 구분자가 공백 -> header가 없음
csvDF1=pd.read_csv(data_file1,sep=' ',header=None)
csvDF1
# Out:
#    0     1   2  3
# 0  1  Hong  10  F
# 1  2  Park  13  F
# 2  3   Kim  12  M
# 3  4   Lee  16  F
# 4  5   Lim  15  M
