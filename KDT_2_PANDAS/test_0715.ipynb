# %%
import pandas as pd

# %% [markdown]
# # 1

# %%
# 1-01

data1={'이름':['메로나','비비빅','죠스바'], '가격':[300,400,250],'재고':[20,3,100]}

data1_df=pd.DataFrame(data1)
data1_df
# Out:
#     이름   가격   재고
# 0  메로나  300   20
# 1  비비빅  400    3
# 2  죠스바  250  100

# %%
# 1-02
print(data1_df.index)
print()

print(data1_df.columns)
print()

print(data1_df.dtypes)
print()

print(data1_df.ndim)
print()

print(data1_df.values)
print()

print(data1_df.shape)
# Out:
# RangeIndex(start=0, stop=3, step=1)
#
# Index(['이름', '가격', '재고'], dtype='object')
#
# 이름    object
# 가격     int64
# 재고     int64
# dtype: object
#
# 2
#
# [['메로나' 300 20]
#  ['비비빅' 400 3]
#  ['죠스바' 250 100]]
#
# (3, 3)

# %%
# 01-3

print(data1_df.가격)
# Out:
# 0    300
# 1    400
# 2    250
# Name: 가격, dtype: int64

# %%
# 01-4

print(data1_df[['이름','재고']])
# Out:
#     이름   재고
# 0  메로나   20
# 1  비비빅    3
# 2  죠스바  100

# %%
# 01-5

print(data1_df.iloc[1,1:])
# Out:
# 가격    400
# 재고      3
# Name: 1, dtype: object

# %%
# 01-6

print(data1_df.iloc[[0,2],[1,2]])
# Out:
#     가격   재고
# 0  300   20
# 2  250  100

# %%
# 01-7

data1_df.index=['일','이','삼']
data1_df
# Out:
#     이름   가격   재고
# 일  메로나  300   20
# 이  비비빅  400    3
# 삼  죠스바  250  100

# %%
# 01-8

data1_df['총가격']=0
data1_df
# Out:
#     이름   가격   재고  총가격
# 일  메로나  300   20    0
# 이  비비빅  400    3    0
# 삼  죠스바  250  100    0

# %%
# 1-09

data1_df.loc['사']=['빵빠레',550,10,0]
data1_df
# Out:
#     이름   가격   재고  총가격
# 일  메로나  300   20    0
# 이  비비빅  400    3    0
# 삼  죠스바  250  100    0
# 사  빵빠레  550   10    0

# %%
# 1-10

data1_df.iloc[1,2]=23
data1_df
# Out:
#     이름   가격   재고  총가격
# 일  메로나  300   20    0
# 이  비비빅  400   23    0
# 삼  죠스바  250  100    0
# 사  빵빠레  550   10    0

# %% [markdown]
# # 2

# %%
# 2-01

data2={'시가':[2000,7400,15450],'고가':[3050,2050,15050],'저가':[2050,2050,15550],'종가':[1980,1980,14900]}

data2_df=pd.DataFrame(data2)

data2_df
# Out:
#       시가     고가     저가     종가
# 0   2000   3050   2050   1980
# 1   7400   2050   2050   1980
# 2  15450  15050  15550  14900

# %%
data2_1=[[ 2000, 3050, 2050, 1980],[ 7500, 2050, 2050, 1980],[15450, 15050, 15550, 14900]]

# %%
data2_1_df=pd.DataFrame(data2_1,columns=['시가','고가','저가','종가'])
data2_1_df
# Out:
#       시가     고가     저가     종가
# 0   2000   3050   2050   1980
# 1   7500   2050   2050   1980
# 2  15450  15050  15550  14900

# %%
# 2-02

print(data2_df.index)
print()

print(data2_df.columns)
print()

print(data2_df.dtypes)
print()

print(data2_df.ndim)
print()

print(data2_df.values)
print()

print(data2_df.shape)
# Out:
# RangeIndex(start=0, stop=3, step=1)
#
# Index(['시가', '고가', '저가', '종가'], dtype='object')
#
# 시가    int64
# 고가    int64
# 저가    int64
# 종가    int64
# dtype: object
#
# 2
#
# [[ 2000  3050  2050  1980]
#  [ 7400  2050  2050  1980]
#  [15450 15050 15550 14900]]
#
# (3, 4)

# %%
# 2-03

data2_df.index=['2024-01-01', '2024-02-01', '2024-03-01']
data2_df
# Out:
#                시가     고가     저가     종가
# 2024-01-01   2000   3050   2050   1980
# 2024-02-01   7400   2050   2050   1980
# 2024-03-01  15450  15050  15550  14900

# %%
# 2-04

data2_df.columns=['Open','High','Low','Close']
data2_df
# Out:
#              Open   High    Low  Close
# 2024-01-01   2000   3050   2050   1980
# 2024-02-01   7400   2050   2050   1980
# 2024-03-01  15450  15050  15550  14900

# %%
# 2-05

print(data2_df.loc['2024-02-01',['High','Close']])
# Out:
# High     2050
# Close    1980
# Name: 2024-02-01, dtype: int64

# %%
# 2-06

data2_df.loc['2024-04-01']=[3200, 3550, 3000, 2990]
data2_df
# Out:
#              Open   High    Low  Close
# 2024-01-01   2000   3050   2050   1980
# 2024-02-01   7400   2050   2050   1980
# 2024-03-01  15450  15050  15550  14900
# 2024-04-01   3200   3550   3000   2990

# %%
# 2-07

data2_df.drop('2024-01-01',inplace=True)
data2_df
# Out:
#              Open   High    Low  Close
# 2024-02-01   7400   2050   2050   1980
# 2024-03-01  15450  15050  15550  14900
# 2024-04-01   3200   3550   3000   2990

# %%
# 2-08

data2_df.loc['2024-03-01','Low']=14000
data2_df
# Out:
#              Open   High    Low  Close
# 2024-02-01   7400   2050   2050   1980
# 2024-03-01  15450  15050  14000  14900
# 2024-04-01   3200   3550   3000   2990

# %%
# 2-09

data2_df['Average']=0
data2_df
# Out:
#              Open   High    Low  Close  Average
# 2024-02-01   7400   2050   2050   1980        0
# 2024-03-01  15450  15050  14000  14900        0
# 2024-04-01   3200   3550   3000   2990        0

# %%
# 2-10

data2_df.loc['Total']=0
data2_df
# Out:
#              Open   High    Low  Close  Average
# 2024-02-01   7400   2050   2050   1980        0
# 2024-03-01  15450  15050  14000  14900        0
# 2024-04-01   3200   3550   3000   2990        0
# Total           0      0      0      0        0

# %% [markdown]
# # 3

# %% [markdown]
# 3-01 : 데이터
#
# 3-02 : 데이터프레임(DataFrame)
#
# 3-03 : 시리즈(Series)
#
# 3-04 : 데이터프레임(DataFrame)
#
# 3-05 : 배열
#
# 3-06 : 시리즈(Series)
#
# 3-07 : 시리즈(Series)
#
# 3-08 : 데이터프레임(DataFrame)
