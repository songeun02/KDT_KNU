# %% [markdown]
# # 아나콘다

# %% [markdown]
#  명령어 -옵션 : 줄여쓸 때
#
#  명령어 --옵션 : 풀네임으로 길게 쓸 때
#
#  명령어 사용법 확인 : 옵션으로 -h
#
#  -> 명령어 -h 또는 명령어 --help

# %% [markdown]
# ## 가상환경 생성

# %% [markdown]
# !! 프로젝트 주제에 사용할 패키지 버전에 맞는 파이썬 버전 선정
#
# 이후 패키지 설치
#
# (base) : 기본환경이 base
#
# conda update -n base conda
# : base라는 conda를 업데이트
#
# -n : name의 약자
#
#
# conda update --all : 현재 있는 모든걸 업데이트
#
# conda env list : 내가 가진 가상환경 리스트

# %% [markdown]
# # 프로그래밍 방법

# %% [markdown]
# OPP :  객체지향 프로그래밍
# - 시뮬레이션 하기 위해 만듦
#
# +) 유지보수가 잘 됨, 하나 끊어도 잘 동작
#
# 대부분 객체지향 프로그램 사용

# %% [markdown]
# 인공지능은 파이썬만으로 가능한 것 x
#
# 의료는 c++로 머신러닝, 딥러닝 가능 / 자바로도 가능

# %% [markdown]
# 인터프리터 언어 : 실행하면 바로 동작하도록 함
#
# 동적 타이핑 : 입력받은 값에 따라 할당 받음

# %% [markdown]
# 함수명 => 소문자로 시작
#
# 클래스명 => 대문자로 시작
#
# 변수명 => 소문자로 시작

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 코드가 입력되면 메모리로 들어가고 힙에서 관리된다.
#
# -> 데이터를 저장한다는 것은 힙에 저장되는 것
#
# -> 저장된 데이터를 처리하는 것은 스택에서 처리한다.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# 힙 : 데이터 크기 고정 x
#
# 정적 : 크기를 고정시켜서 저장
#
# - 정수, 실수 저장하는 메모리의 크기가 다르게 정의되어 있다.
# - int a = 5;
#   - int로 정의되어 있으므로 4byte 사용
#   - 앞에 정의된 변수의 타입으로 공간 할당
#
# 동적 : 크기 고정 없이 저장
# - a = 5;
#   - int로 정의되어 있지 않으므로 5를 먼저 저장하고 실행 되면 공간 할당
#
#
# => 파이썬에서는 동적 메모리 할당 사용
#
#   => 데이터의 주소값을 저장하는 참조 변수로 사용

# %% [markdown]
# # 변수 살펴보기

# %% [markdown]
# 변수란 ?
#
# (1) 데이터를 저장하고 있는 메모리 공간의 이름
#
# (2) 데이터가 저장된 주소를 저장하고 있는 메모리 공간의 이름
#
# - 파이썬 데이터 저장 방식은 (2) 사용
#
# - 문법 : 변수명 = 데이터

# %%
# 힙에 2024가 변수 없이 저장되어 있다면 Python Memory Manager가 사용 못 하게 처리하므로 변수 지정 필요
# 2024의 저장된 주소를 year에 저장한다

year=2024

# 나이 21세를 메모리 저장
age = 21

# 나이를 22세로 변경하여 저장
age = 22

# -> age를 22로 재 지정하므로 ppm이 돌아보다가 21을 참조하는 것이 없으면 처리

# %% [markdown]
# 오른쪽에 있는 값들은 힙 영역에 저장된다
